# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\evgenia.zmitrochenko\\Documents\\Task\\Rayoni_cities_mln\\admin_level_8.csv', sep=';')
# Out:
# C:\Users\evgenia.zmitrochenko\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (16,25,26,27,31,40,44,45,46,52,56,59,63,65,66,67,68,69,70,71,72,73,74,75,76,77,78,81,88,89,90,91,92,93,95,101,102,103,104,106,107,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import pygeoj
testfile = pygeoj.load("C:\\Users\\evgenia.zmitrochenko\\Documents\\Task\\Rayoni_cities_mln\\admin_level_8.geojson")
for feature in testfile:
    print feature.geometry.type
    print feature.geometry.coordinates
# Out:
#   File "<ipython-input-24-42fe7c7f789e>", line 4
#     print feature.geometry.type
#                 ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(int feature.geometry.type)?

# %%
import importlib
importlib.reload(yandex-maps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-8dc013120fe9> in <module>()
#       1 import importlib
# ----> 2 importlib.reload(yandex-maps)
#
# NameError: name 'yandex' is not defined

# %%
# !pip install yandex-maps
#!pip install  yandex-maps-0.7.tar.gz
#"C:\\Users\\evgenia.zmitrochenko\\Documents\\Docs\\
# Out:
# ...
#   Using cached yandex-maps-0.7.tar.gz
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\EVGENI~1.ZMI\AppData\Local\Temp\pip-build-i_9juxvm\yandex-maps\setup.py", line 6, in <module>
#         reload(sys).setdefaultencoding("UTF-8")
#     NameError: name 'reload' is not defined
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in C:\Users\EVGENI~1.ZMI\AppData\Local\Temp\pip-build-i_9juxvm\yandex-maps\

# %%
from yandex_maps import api
# api_key = 'my_api_key'
# pos = api.geocode(api_key, u'Санкт-Петербург, Бумажная 4')
# print(pos)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-86bc59c40535> in <module>()
# ----> 1 from yandex_maps import api
#       2 # api_key = 'my_api_key'
#       3 # pos = api.geocode(api_key, u'Санкт-Петербург, Бумажная 4')
#       4 # print(pos)
#
# ModuleNotFoundError: No module named 'yandex_maps'

# %%
from geopandas.tools import geocode


key = 'AIzaSyAwNVHAtkbKlPs-EEs3OYqbnxzaYfDF2_8'

# # Geocode addresses
geo = geocode('Лопатино 50 лет Октября 61', api_key=key)

# %%
geo
# Out:
#    address                  geometry
# 0      NaN  GEOMETRYCOLLECTION EMPTY

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
location = geolocator.geocode("Пархикасы Садовая 2")
print(location.raw)#['lat'])#, location.raw['lon'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-4fd1a35cf763> in <module>()
#       2 geolocator = Nominatim()
#       3 location = geolocator.geocode("Пархикасы Садовая 2")
# ----> 4 print(location.raw)#['lat'])#, location.raw['lon'])
#
# AttributeError: 'NoneType' object has no attribute 'raw'

# %%
data.head()
# Out:
#                                                  WKT  \
# 0  MULTIPOLYGON (((34.8866613 44.849171,34.884645...
# 1  MULTIPOLYGON (((33.6827245 44.8998062,33.68468...
# 2  MULTIPOLYGON (((33.6216177 44.8180215,33.61537...
# 3  MULTIPOLYGON (((28.7527973 56.7073346,28.75091...
# 4  MULTIPOLYGON (((52.85717 54.5372907,52.8569939...
#
#                          name                    name__ru  \
# 0  Весёловский сельский совет  Весёловский сельский совет
# 1      Табачненский сельсовет      Табачненский сельсовет
# 2         Угловский сельсовет         Угловский сельсовет
# 3  городское поселение Опочка                         NaN
# 4                    Бугульма                    Бугульма
#
#                      name__uk        boundary  \
# 0   Веселівська сільська рада  administrative
# 1  Табачненська сільська рада  administrative
# 2     Углівська сільська рада  administrative
# 3                         NaN  administrative
# 4                         NaN  administrative
#
# ...

# %%
data.is_in__country_code.unique()
# Out:
# array(['UA', nan, 'RU'], dtype=object)

# %%
data_ru = data[data['is_in__country_code'] != 'UA']

# %%
data_ru.columns
# Out:
# Index(['WKT', 'name', 'name__ru', 'name__uk', 'boundary', 'wikipedia',
#        'admin_level', 'is_in__country_code', 'koatuu', 'addr__country',
#        ...
#        'name__et', 'oktmo', 'admin_cеntre', 'alt_name__en', 'wikipedia__ru',
#        'name__lv', 'postal_code', 'discussion__url', 'name__sv',
#        'old_name__en'],
#       dtype='object', length=109)

# %%
data[data['official_status'] == 'ru:внутригородская территория города федерального значения']#.shape()
# Out:
#                                                      WKT  \
# 23     MULTIPOLYGON (((37.6071633 55.8793205,37.60676...
# 427    MULTIPOLYGON (((37.5744493 55.7463273,37.57413...
# 733    MULTIPOLYGON (((37.4698854 55.8431779,37.46884...
# 1345   MULTIPOLYGON (((37.590735300000013 55.9136561,...
# 1347   MULTIPOLYGON (((37.8426838 55.749073,37.828083...
# 1348   MULTIPOLYGON (((37.7123792 55.6846586,37.71195...
# 1350   MULTIPOLYGON (((37.8904033 55.7420847,37.89008...
# 1487   MULTIPOLYGON (((37.6035767 55.5645916,37.60213...
# 1825   MULTIPOLYGON (((37.8435518 55.8149722,37.84282...
# 2014   MULTIPOLYGON (((37.7304381 55.6130263,37.73015...
# 2026   MULTIPOLYGON (((37.6652416 55.6862244,37.64392...
# 2055   MULTIPOLYGON (((37.9451627 55.7208118,37.94299...
# 2057   MULTIPOLYGON (((37.9674277 55.716249,37.962053...
# 2669   MULTIPOLYGON (((37.734893 55.6874275,37.734491...
# 2671   MULTIPOLYGON (((37.6271573 55.6726145,37.62629...
# ...

# %%
data.wikipedia.unique()
# Out:
# array(['ru:Весёловский сельский совет (Судакский горсовет)',
#        'uk:Табачненська сільська рада (Бахчисарайський район)',
#        'uk:Углівська сільська рада', ..., 'ru:Бокинский сельсовет',
#        'ru:Норово-Ротаевское сельское поселение',
#        'ru:Нижнетуровское сельское поселение'], dtype=object)

# %%
data[data['name'] != data['name__ru']]
# Out:
#                                                      WKT  \
# 3      MULTIPOLYGON (((28.7527973 56.7073346,28.75091...
# 5      MULTIPOLYGON (((39.5057831 55.919473,39.505595...
# 6      MULTIPOLYGON (((38.0701509 44.9316998,38.06885...
# 7      MULTIPOLYGON (((35.9264203 57.0107708,35.92301...
# 8      MULTIPOLYGON (((28.053469 58.0084475,28.052609...
# 9      MULTIPOLYGON (((45.7145416 53.0738846,45.70883...
# 10     MULTIPOLYGON (((38.1376604 56.4377078,38.11324...
# 11     MULTIPOLYGON (((38.3587511 56.5732704,38.33863...
# 12     MULTIPOLYGON (((36.2430601 56.909523,36.241925...
# 13     MULTIPOLYGON (((50.1720826 53.0820025,50.17050...
# 14     MULTIPOLYGON (((50.4185152 53.2436821,50.41093...
# 15     MULTIPOLYGON (((50.3859275 53.2878094,50.37401...
# 17     MULTIPOLYGON (((43.7210025 56.440301,43.713906...
# 18     MULTIPOLYGON (((58.2211545 58.2160283,58.21815...
# 19     MULTIPOLYGON (((30.2391956 59.8639293,30.22867...
# ...

# %%
data[['name', 'population__source']]
# Out:
#                                        name population__source
# 0                Весёловский сельский совет                NaN
# 1                    Табачненский сельсовет                NaN
# 2                       Угловский сельсовет                NaN
# 3                городское поселение Опочка                NaN
# 4                                  Бугульма                NaN
# 5               городское поселение Петушки                NaN
# 6                               Крымское ГП                NaN
# 7      городское поселение Васильевский Мох                NaN
# 8             Территория Залитских островов                NaN
# 9                               город Сурск                NaN
# 10                сельское поселение Реммаш                NaN
# 11            Селковское сельское поселение                NaN
# 12                 городское поселение Орша                NaN
# 13                              Придорожный                NaN
# ...
